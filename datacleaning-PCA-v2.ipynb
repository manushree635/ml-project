# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# Disable warnings
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('df_clean.csv')

# %%
df.head()
# Out:
#             created_at  total_items  subtotal  num_distinct_items  \
# 0  2015-02-06 22:24:17            4      3441                   4
# 1  2015-02-10 21:49:25            1      1900                   1
# 2  2015-01-22 20:39:28            1      1900                   1
# 3  2015-02-03 21:21:45            6      6900                   5
# 4  2015-02-15 02:40:36            3      3900                   3
#
#    min_item_price  max_item_price  total_onshift_dashers  total_busy_dashers  \
# 0             557            1239                   33.0                14.0
# 1            1400            1400                    1.0                 2.0
# 2            1900            1900                    1.0                 0.0
# 3             600            1800                    1.0                 1.0
# 4            1100            1600                    6.0                 6.0
#
#    total_outstanding_orders  estimated_order_place_duration  ...  \
# 0                      21.0                             446  ...
# 1                       2.0                             446  ...
# 2                       0.0                             446  ...
# 3                       2.0                             446  ...
# 4                       9.0                             446  ...
#
#    store_primary_category_spanish  store_primary_category_steak  \
# 0                           False                         False
# 1                           False                         False
# 2                           False                         False
# 3                           False                         False
# 4                           False                         False
#
#    store_primary_category_sushi  store_primary_category_tapas  \
# 0                         False                         False
# 1                         False                         False
# 2                         False                         False
# 3                         False                         False
# 4                         False                         False
#
#    store_primary_category_thai  store_primary_category_turkish  \
# 0                        False                           False
# 1                        False                           False
# 2                        False                           False
# 3                        False                           False
# 4                        False                           False
#
#    store_primary_category_vegan  store_primary_category_vegetarian  \
# 0                         False                              False
# 1                         False                              False
# 2                         False                              False
# 3                         False                              False
# 4                         False                              False
#
#    store_primary_category_vietnamese  Target Variable
# 0                              False           3779.0
# 1                              False           4024.0
# 2                              False           1781.0
# 3                              False           3075.0
# 4                              False           2390.0
#
# [5 rows x 107 columns]

# %%
df['created_at'] = pd.to_datetime(df['created_at'])

# %%
# Drop 'created_at' as it's not needed for modeling (or extract features if necessary)
X = df.drop(['Target Variable', 'created_at'], axis=1)
y = df['Target Variable']

# %%
# Ensure all boolean columns are converted to integers (True/False to 1/0)
X = X.applymap(lambda x: 1 if x == True else (0 if x == False else x))

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# Convert the DataFrame to a NumPy array
X_array = X.values

# %%
from sklearn.mixture import GaussianMixture

# %%
# Step 1.5: Scale the Data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# Step 2: Outlier Detection using Gaussian Mixture Models (GMM)

# Fit a GMM with one component to model the main distribution
gmm = GaussianMixture(n_components=1, covariance_type='full', random_state=42)
# gmm.fit(X_array)
gmm.fit(X_scaled)
# Out:
# GaussianMixture(random_state=42)

# %%
# Compute the log-likelihood of each sample
log_likelihood = gmm.score_samples(X)

# %%
# Visualize the distribution of log-likelihood scores
plt.figure(figsize=(10, 6))
sns.histplot(log_likelihood, bins=50, kde=True)
plt.title('Distribution of Log-Likelihood Scores from GMM')
plt.xlabel('Log-Likelihood Score')
plt.ylabel('Frequency')
plt.show()

# %%
# Set a threshold to identify outliers (e.g., lower 1% quantile)
threshold = np.quantile(log_likelihood, 0.01)

# %%
# Identify outliers
outliers = log_likelihood < threshold

# %%
# Visualize the threshold on the histogram
plt.figure(figsize=(10, 6))
sns.histplot(log_likelihood, bins=50, kde=True)
plt.axvline(threshold, color='red', linestyle='--', label='Outlier Threshold')
plt.title('Distribution of Log-Likelihood Scores with Outlier Threshold')
plt.xlabel('Log-Likelihood Score')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %%
# Remove outliers from the dataset
X_clean = X_array[~outliers]
y_clean = y.values[~outliers]

# %%
# Optional: Print the number of outliers detected
print(f"Number of outliers detected: {np.sum(outliers)}")
# Out:
# Number of outliers detected: 1969

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(svd_solver='randomized', random_state=42)

# %%
pca.fit(X_clean)
# Out:
# PCA(random_state=42, svd_solver='randomized')

# %%
var_ratio={}
for n in range(1,10):
    pca=PCA(n_components=n)
    pca_components = pca.fit(X_clean)
    var_ratio[n]=sum(pca.explained_variance_ratio_)

# %%
var_ratio
# Out:
# {1: 0.8317329633835852,
#  2: 0.952969718369751,
#  3: 0.981137781086209,
#  4: 0.9960462075925854,
#  5: 0.9986444954813977,
#  6: 0.9999246266572118,
#  7: 0.9999607723421887,
#  8: 0.9999807868223367,
#  9: 0.9999977923756613}

# %%
plt.figure(figsize=(10, 6))
plt.plot(np.cumsum(pca.explained_variance_ratio_), marker='o')
plt.title('Cumulative Explained Variance by PCA Components')
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Explained Variance')
plt.grid(True)
plt.show()

# %%
# Scree plot of individual explained variance
plt.figure(figsize=(10, 6))
plt.bar(range(1, len(pca.explained_variance_ratio_)+1), pca.explained_variance_ratio_)
plt.title('Explained Variance Ratio of Each Principal Component')
plt.xlabel('Principal Component')
plt.ylabel('Explained Variance Ratio')
plt.show()

# %%
final = PCA(n_components=3).fit(X_clean)
reduced_dim=final.fit_transform(X_clean)
# store it in a new data frame
new_data= pd.DataFrame(data = reduced_dim, columns = ['principal component 1', 'principal component 2',
                                                        'principal component 3'])

new_data.head()
# Out:
#    principal component 1  principal component 2  principal component 3
# 0             842.326790            -168.751800              41.598702
# 1            -613.959562             804.737051            -173.316053
# 2            -502.589251            1500.203512            -111.510734
# 3            4340.969613            -291.595638             -17.852814
# 4            1377.033611             406.593081             -92.038120

# %%
# Optional: Print the shape of the data after PCA
print(f"Original number of features: {X_clean.shape[1]}")
print(f"Reduced number of features after PCA: {new_data.shape[1]}")
# Out:
# Original number of features: 105
# Reduced number of features after PCA: 3

# %%
# Visualize the first two principal components
plt.figure(figsize=(10, 6))
plt.scatter(reduced_dim[:, 0], reduced_dim[:, 1], c=y_clean, cmap='viridis', alpha=0.5)
plt.title('Data Projected onto First Two Principal Components')
plt.xlabel('First Principal Component')
plt.ylabel('Second Principal Component')
plt.colorbar(label='Target Variable')
plt.show()

# %% [markdown]
# ### Regression Model for evaluating the cleaned and transformed dataset
# 1) Split Data into Train, Test
# 2) Train model on cleaned train data for X and cleaned train data for Y (output)
# 3) Use Ridge Regression (L2 Loss) to predict values for Y
# 4) Calculate MSE loss for Ridge Regression Model
# 4) Use Linear Regression to predict to predict values for Y
# 6) Calculate MSE loss for Linear Regression Model
# 7) Evaluate perfomance on non-PCA vs PCA data

# %%
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, y, test_size=0.2, random_state=20)

# %%
Y_avg = y.mean()
print(Y_avg)
# Out:
# 2908.8978526298683

# %%
# Ridge - Linear least squares with l2 regularization.
# Ridge - Minimizes the objective function
# linear_model = LinearRegression()
# linear_model.fit(X_train, Y_train)

linear_model2 = LinearRegression()
linear_model2.fit(X_train, Y_train)

linear_model3 = LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1)
linear_model3.fit(X_train, Y_train)
# Out:
# LinearRegression(n_jobs=1)

# %%
r2_score = linear_model3.score(X_train, Y_train)
print(r2_score)
# Out:
# 0.0009589941961161141

# %%
r2_score = linear_model3.score(X_test, Y_test)
print(r2_score)
# Out:
# 0.14826555770834782

# %%
pred_linear= linear_model3.predict(X_train)
print(np.sqrt(mean_squared_error(Y_train, pred_linear)))
# Out:
# 21510.32692730373

# %%
pred_linear_test = linear_model3.predict(X_test)
print(np.sqrt(mean_squared_error(Y_test, pred_linear_test)))
# Out:
# 1046.4452787427133

# %%
pred_linear= linear_model3.predict(X_train)
print(np.sqrt(mean_squared_error(Y_train, pred_linear)))
# Out:
# 21510.32692730373

# %%
plt.figure(figsize=(10, 6))
plt.scatter(Y_test, pred_linear_test, color='blue', edgecolor='k', alpha=0.6)
plt.plot([Y_test.min(), Y_test.max()], [Y_test.min(), Y_test.max()], color='red', lw=2)
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.title("Actual vs Predicted Values")
plt.show()

# %%
# linear_model4 = LinearRegression().fit()
# pred_linear= linear_model4.predict(X_train)
# print(np.sqrt(mean_squared_error(Y_train, pred_linear)))

# pred_linear_test= linear_model4.predict(X_test)
# print(np.sqrt(mean_squared_error(Y_test, pred_linear_test)))
